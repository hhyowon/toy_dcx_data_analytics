# %% [markdown]
# ## Eye Review 홈페이지에서 안과 리뷰 스크래핑 하기
# - toy_dcx_data_analytics (git)
# - 환자 페인 포인트 찾기
# - 댓글 최소 1천건 이상(스크래핑 사이트 3개 이상)
# - DB 컬럼 : 작성자, 작성일, 내용, 별점

# %% [markdown]
# ### chorme browser open
# - 아이리뷰 :  https://xn--oy2b21f01h9lc.com/

# %%
from selenium import webdriver
import pandas as pd

# %%
options = webdriver.ChromeOptions()
options.add_argument("--window-size=1560,840")
browser = webdriver.Chrome(executable_path='../../chromedriver.exe', options=options) #webdriver_selenium과 web을 연결해주기위함. 
browser.get('https://xn--oy2b21f01h9lc.com/')
browser.implicitly_wait(10)

# %% [markdown]
# ### Login
# - 로그인 버튼 클릭 tag : div.row.row--small.user-menu.align-center.justify-center > div:nth-child(1)
# - user_email tag : #input-3127
# - password tag : #input-1571
# - submit button tag :div.login-row.login-row--submit.mt-16.mt-md-20 > button

# %%
browser.find_element_by_css_selector('div.row.row--small.user-menu.align-center.justify-center > div:nth-child(1)').click()

# %%
browser.find_element_by_css_selector('#input-1570').send_keys('circle0605@naver.com')
browser.find_element_by_css_selector('#input-1571').send_keys('507303')

# %%
browser.find_element_by_css_selector('div.login-row.login-row--submit.mt-16.mt-md-20 > button').click()

# %% [markdown]
# ### 안과후기
# - 안과후기tag : div.header__gnb.justify-center > ul > li:nth-child(2)
# - 더보기 tag : div.mt-40.mt-md-70 > div > button
# - 작성자, (작성일), 내용, 별점 , 병원명
#    - 해당 사이트에는 작성일이 게시되어 있지 않아 가져오지 못함

# %%
browser.find_element_by_css_selector('div.header__gnb.justify-center > ul > li:nth-child(2)').click()

# %%
# browser.find_element_by_css_selector('div.mt-40.mt-md-70 > div > button').click() #리뷰더보기 검토

# %%
# 리뷰 전체 더보기 : 예외가 발생할 때까지 계속해서 버튼을 클릭(추가 더보기 없을때)
while True :
    try :
        browser.find_element_by_css_selector('div.mt-40.mt-md-70 > div > button').click()
    except :
        break

# %% [markdown]
# #### 리뷰 작성자
# - 작성자 tag : .font-size-12.font-size-md-14.grey-a--text.ml-6

# %%
review_author = browser.find_elements_by_css_selector('.font-size-12.font-size-md-14.grey-a--text.ml-6')
type(review_author), type(review_author[0])
# Out:
# (list, selenium.webdriver.remote.webelement.WebElement)

# %%
# 리뷰 작성자 리스트
review_author_list = []
for review_author in review_author :
    review_author_list.append(review_author.text)

review_author_list
# Out:
# ['',
#  '',
#  '',
#  '클린한 오빠님',
#  '깜찍한 북극곰님',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '클린한 오오리님',
#  '파워풀한 날다람쥐님',
#  '여행 중인 언니님',
#  '놀라운 붕붕이님',
#  '감옥의 풍뎅이님',
#  '여행 중인 풍뎅이님',
#  '깜찍한 곰님',
#  '천국의 햄스터님',
#  '귀여운 누나님',
#  '클린한 undefined님',
#  '감옥의 오오리님',
#  '감옥의 언니님',
#  '그대의 누나님',
#  '클린한 햄쥐님',
#  '감옥의 쌩쌩이님',
#  '각막의 언니님',
#  '각막의 다람쥐님',
#  '파워풀한 누나님',
#  '각막의 붕붕이님',
#  '깜찍한 붕붕이님',
#  '탈출한 다람쥐님',
#  '탈출한 햄스터님',
#  '탈출한 거북이님',
#  '구르는 거북이님',
#  '날라가는 붕붕이님',
#  '깜찍한 그대님',
#  '곰을 잡은 형님',
#  '감옥의 오리님',
#  '감옥의 언니님',
#  '감옥의 곰님',
#  '해민맘님',
#  '날라가는 오오리님',
#  '파워풀한 그대님',
#  '각막의 거북이님',
#  '궁금한 햄쥐님',
#  '깜찍한 날다람쥐님',
#  '깜찍한 햄쥐님',
#  '인형 잡은 풍뎅이님',
#  '그대의 누나님',
#  '곰을 잡은 다람쥐님',
#  '날라가는 오오리님',
#  '신비로운 날다람쥐님',
#  '천국의 형님',
#  '구르는 거북이님',
#  '굴러가는 개구리님',
#  '놀라운 풍뎅이님',
#  '곰을 잡은 오리님',
#  '세상좋은 북극곰님',
#  '그대의 소시지님',
#  '놀라운 다람쥐님',
#  '궁금한 오리님',
#  '세상좋은 오리님',
#  '인형 잡은 그대님',
#  '인형 잡은 형님',
#  '날라가는 오리님',
#  '곰을 잡은 날다람쥐님',
#  '귀여운 오오리님',
#  '탈출한 개구리님',
#  '귀여운 누나님',
#  '탈출한 곰님',
#  '감옥의 쌩쌩이님',
#  '파워풀한 날다람쥐님',
#  '날라가는 날다람쥐님',
#  '날으는 풍뎅이님',
#  '인형 잡은 북극곰님',
#  '여행 중인 북극곰님',
#  '감옥의 붕붕이님',
#  '뛰는 날다람쥐님',
#  '놀라운 그대님',
#  '여행 중인 소시지님',
#  '인형 잡은 소시지님',
#  '구르는 언니님',
#  '각막의 햄쥐님',
#  '감옥의 곰님',
#  '세상좋은 북극곰님',
#  '천국의 쌩쌩이님',
#  '클린한 형님',
#  '깜찍한 누나님',
#  '구르는 곰님',
#  '인형 잡은 햄찌님',
#  '날라가는 undefined님',
#  '인형 잡은 북극곰님',
#  '각막의 형님',
#  '클린한 햄쥐님',
#  '날라가는 곰님',
#  '신비로운 날다람쥐님',
#  '뛰는 거북이님',
#  '구르는 그대님',
#  '신비로운 풍뎅이님',
#  '파워풀한 북극곰님',
#  '천국의 거북이님',
#  '요니요니님',
#  '여행 중인 햄스터님',
#  '인형 잡은 형님',
#  '날라가는 북극곰님',
#  '굴러가는 개구리님',
#  '궁금한 햄쥐님',
#  '날라가는 언니님',
#  '뛰는 곰님',
#  'shyun8883님',
#  '못멧지님',
#  '천국의 날다람쥐님',
#  '니모파이님',
#  '날으는 undefined님',
#  '날라가는 언니님',
#  '날으는 undefined님',
#  '인형 잡은 풍뎅이님',
#  '깜찍한 햄스터님',
#  '세상좋은 햄찌님',
#  '인형 잡은 오빠님',
#  '굴러가는 오빠님',
#  '날라가는 곰님',
#  '여행 중인 오빠님',
#  '각막의 풍뎅이님',
#  '구르는 햄찌님',
#  '날라가는 햄찌님',
#  '세상좋은 날다람쥐님',
#  '세상좋은 오리님',
#  '천국의 누나님',
#  '파워풀한 햄찌님',
#  '날라가는 개구리님',
#  '깜찍한 날다람쥐님',
#  '깜찍한 날다람쥐님',
#  '천국의 쌩쌩이님',
#  '천국의 undefined님',
#  '신비로운 북극곰님',
#  '날으는 북극곰님',
#  '궁금한 붕붕이님',
#  '감옥의 다람쥐님',
#  '궁금한 다람쥐님',
#  '탈출한 햄찌님',
#  '천국의 소시지님',
#  '뛰는 햄찌님',
#  '놀라운 undefined님',
#  '깜찍한 오오리님',
#  '각막의 언니님',
#  '귀여운 undefined님',
#  '각막의 풍뎅이님',
#  '날라가는 개구리님',
#  '감옥의 햄찌님',
#  '세상좋은 날다람쥐님',
#  '세상좋은 북극곰님',
#  '굴러가는 날다람쥐님',
#  '신비로운 개구리님',
#  '놀라운 햄찌님',
#  '곰을 잡은 거북이님',
#  '인형 잡은 그대님',
#  '그대의 햄스터님',
#  '날으는 언니님',
#  '세상좋은 북극곰님',
#  '신비로운 언니님',
#  '파워풀한 풍뎅이님',
#  '귀여운 소시지님',
#  '여행 중인 쌩쌩이님',
#  '클린한 날다람쥐님',
#  '구르는 소시지님',
#  '봄봄봄님',
#  '귀여운 날다람쥐님',
#  '세상좋은 소시지님',
#  '천국의 햄스터님',
#  '신비로운 오리님',
#  '신비로운 곰님',
#  '천국의 곰님',
#  '파워풀한 오오리님',
#  '천국의 언니님',
#  '놀라운 햄스터님',
#  '귀여운 쌩쌩이님',
#  '하늘다람쥐님',
#  '그대의 북극곰님',
#  '뛰는 오오리님',
#  '날라가는 누나님',
#  '클린한 붕붕이님',
#  '그대의 개구리님',
#  '궁금한 개구리님',
#  '곰을 잡은 오빠님',
#  '귀여운 그대님',
#  '굴러가는 곰님',
#  '뛰는 곰님',
#  '궁금한 형님',
#  '각막의 오빠님',
#  '파워풀한 오빠님',
#  '굴러가는 소시지님',
#  '신비로운 오빠님',
#  '파워풀한 형님',
#  '날라가는 undefined님',
#  '궁금한 형님',
#  '천국의 언니님',
#  '신비로운 오오리님',
#  '라식남님',
#  '그대의 날다람쥐님',
#  '클린한 그대님',
#  '인형 잡은 거북이님',
#  '구르는 쌩쌩이님',
#  '파워풀한 소시지님',
#  '날으는 누나님',
#  '신비로운 오오리님',
#  '날라가는 햄찌님',
#  '굴러가는 개구리님',
#  '인형 잡은 언니님',
#  '여행 중인 undefined님',
#  '여행 중인 풍뎅이님',
#  '파워풀한 오오리님',
#  '세상좋은 오오리님',
#  '탈출한 소시지님',
#  '클린한 undefined님',
#  '그대의 누나님',
#  '뛰는 거북이님',
#  '궁금한 오빠님',
#  '그대의 누나님',
#  '뛰는 풍뎅이님',
#  '천국의 햄스터님',
#  '뛰는 누나님',
#  '귀여운 언니님',
#  '굴러가는 다람쥐님',
#  '탈출한 날다람쥐님',
#  '천국의 언니님',
#  '깜찍한 오오리님',
#  '곰을 잡은 언니님',
#  '뛰는 붕붕이님',
#  '세상좋은 그대님',
#  '탈출한 풍뎅이님',
#  '세상좋은 날다람쥐님',
#  '각막의 개구리님',
#  '세상좋은 개구리님',
#  '날라가는 날다람쥐님',
#  '클린한 다람쥐님',
#  '놀라운 쌩쌩이님',
#  '뛰는 북극곰님',
#  '날라가는 그대님',
#  '궁금한 오오리님',
#  '뛰는 형님',
#  '천국의 날다람쥐님',
#  '천국의 누나님',
#  '여행 중인 곰님',
#  '날라가는 undefined님',
#  '궁금한 날다람쥐님',
#  '깜찍한 북극곰님',
#  '깜찍한 햄스터님',
#  '파워풀한 쌩쌩이님',
#  '콩이이모님',
#  '놀라운 곰님',
#  '여행 중인 언니님',
#  '여행 중인 undefined님',
#  '굴러가는 형님',
#  '천국의 누나님',
#  '감옥의 햄쥐님',
#  '구르는 개구리님',
#  '신비로운 햄찌님',
#  '천국의 쌩쌩이님',
#  '날으는 다람쥐님',
#  '굴러가는 날다람쥐님',
#  '인형 잡은 undefined님',
#  '귀여운 개구리님',
#  '인형 잡은 햄찌님',
#  '구르는 곰님',
#  '구르는 오빠님',
#  '클린한 햄스터님',
#  '탈출한 오빠님',
#  '날라가는 쌩쌩이님',
#  '감옥의 오리님',
#  '감옥의 undefined님',
#  '인형 잡은 풍뎅이님',
#  '각막의 누나님',
#  '굴러가는 붕붕이님',
#  '감옥의 북극곰님',
#  '놀라운 개구리님',
#  '여행 중인 쌩쌩이님',
#  '날으는 형님',
#  '날라가는 오오리님',
#  '구르는 오빠님',
#  '깜찍한 풍뎅이님',
#  '클린한 햄쥐님',
#  '구르는 그대님',
#  '감옥의 붕붕이님',
#  '귀여운 햄스터님',
#  '탈출한 풍뎅이님',
#  '이따금씩님',
#  '인형 잡은 소시지님',
#  '신비로운 언니님',
#  '감옥의 날다람쥐님',
#  '궁금한 다람쥐님',
#  '깜찍한 날다람쥐님',
#  '탈출한 형님',
#  '세상좋은 오빠님',
#  '그대의 언니님',
#  '날라가는 북극곰님',
#  '깜찍한 햄쥐님',
#  '천국의 형님',
#  '쿠크다스님',
#  '곰을 잡은 언니님',
#  '탈출한 오리님',
#  '놀라운 오오리님',
#  '여행 중인 오리님',
#  '천국의 undefined님',
#  '놀라운 개구리님',
#  '감옥의 햄쥐님',
#  '그대의 오오리님',
#  '굴러가는 풍뎅이님',
#  '탈출한 그대님',
#  '여행 중인 형님',
#  '탈출한 햄스터님',
#  '궁금한 형님',
#  '궁금한 오빠님',
#  '굴러가는 소시지님',
#  '놀라운 거북이님',
#  '귀여운 개구리님',
#  '놀라운 오오리님',
#  '곰을 잡은 오리님',
#  '세상좋은 붕붕이님',
#  '귀여운 날다람쥐님',
#  '귀여운 북극곰님',
#  '파워풀한 날다람쥐님',
#  '파워풀한 날다람쥐님',
#  '날라가는 오리님',
#  '호랑니님',
#  '귀여운 오리님',
#  '날라가는 거북이님',
#  '뛰는 그대님',
#  '감옥의 풍뎅이님',
#  '각막의 개구리님',
#  '클린한 풍뎅이님',
#  '그대의 쌩쌩이님',
#  '세상좋은 날다람쥐님',
#  '파워풀한 다람쥐님',
#  '인형 잡은 undefined님',
#  '날으는 다람쥐님',
#  '찔레꽃아이님',
#  '깜찍한 거북이님',
#  '클린한 오빠님',
#  '인형 잡은 햄스터님',
#  '세상좋은 다람쥐님',
#  '뛰는 날다람쥐님',
#  '감옥의 다람쥐님',
#  '탈출한 오리님',
#  '천국의 햄스터님',
#  '파워풀한 개구리님',
#  '세상좋은 소시지님',
#  '신비로운 풍뎅이님',
#  '파워풀한 undefined님',
#  '곰을 잡은 붕붕이님',
#  '희랑님',
#  '깜찍한 형님',
#  '파워풀한 누나님',
#  '각막의 다람쥐님',
#  '구르는 오리님',
#  '클린한 붕붕이님',
#  '여행 중인 북극곰님',
#  '귀여운 다람쥐님',
#  '놀라운 곰님',
#  '세상좋은 누나님',
#  '탈출한 undefined님',
#  '클린한 다람쥐님',
#  '감옥의 오빠님',
#  '천국의 햄쥐님',
#  '힝가님',
#  '파워풀한 undefined님',
#  '그대의 쌩쌩이님',
#  '뛰는 개구리님',
#  '뛰는 쌩쌩이님',
#  '굴러가는 언니님',
#  '굴러가는 쌩쌩이님',
#  '구르는 햄찌님',
#  '천국의 날다람쥐님',
#  '궁금한 언니님',
#  '놀라운 undefined님',
#  '그대의 오빠님',
#  '각막의 undefined님',
#  '세상좋은 쌩쌩이님',
#  '굴러가는 다람쥐님',
#  '세상좋은 쌩쌩이님',
#  '인형 잡은 햄쥐님',
#  '인형 잡은 햄쥐님',
#  '날라가는 형님',
#  '놀라운 곰님',
#  '세상좋은 풍뎅이님',
#  '굴러가는 개구리님',
#  '파워풀한 언니님',
#  '파워풀한 붕붕이님',
#  '궁금한 쌩쌩이님',
#  '날으는 북극곰님',
#  '세상좋은 그대님',
#  '깜찍한 햄찌님',
#  '그대의 그대님',
#  '깜찍한 누나님',
#  '세상좋은 개구리님',
#  '각막의 형님',
#  '날라가는 언니님',
#  '뛰는 그대님',
#  '깜찍한 붕붕이님',
#  '여행 중인 오빠님',
#  '클린한 햄스터님',
#  '여행 중인 거북이님',
#  '천국의 오빠님',
#  '탈출한 햄스터님',
#  '뛰는 오리님',
#  '날라가는 거북이님',
#  '여행 중인 날다람쥐님',
#  '날으는 undefined님',
#  '신비로운 북극곰님',
#  '세상좋은 북극곰님',
#  '츠네오님',
#  '뛰는 다람쥐님',
#  '신비로운 풍뎅이님',
#  '클린한 소시지님',
#  '세상좋은 풍뎅이님',
#  '감옥의 소시지님',
#  '구르는 그대님',
#  '파워풀한 오리님',
#  '파워풀한 누나님',
#  '날라가는 햄쥐님',
#  '모쓰님',
#  '감옥의 곰님',
#  '탈출한 오리님',
#  '인형 잡은 북극곰님',
#  '구르는 다람쥐님',
#  '뛰는 개구리님',
#  '감옥의 거북이님',
#  '날라가는 곰님',
#  '뛰는 거북이님',
#  '파워풀한 형님',
#  '각막의 그대님',
#  '탈출한 날다람쥐님',
#  '토실토실님',
#  '여행 중인 소시지님',
#  '궁금한 곰님',
#  '뛰는 날다람쥐님',
#  '감옥의 누나님',
#  '천국의 undefined님',
#  '감옥의 오빠님',
#  '땡글땡글님',
#  '뛰는 붕붕이님',
#  '그대의 누나님',
#  '궁금한 오오리님',
#  '탈출한 풍뎅이님',
#  '미아님',
#  '감옥의 형님',
#  '여행 중인 그대님',
#  '신비로운 다람쥐님',
#  '곰을 잡은 북극곰님',
#  '곰을 잡은 북극곰님',
#  '세상좋은 햄쥐님',
#  '파워풀한 풍뎅이님',
#  '날으는 날다람쥐님',
#  '그대의 붕붕이님',
#  '천국의 오오리님',
#  '그대의 오리님',
#  '날으는 거북이님',
#  '깜찍한 햄쥐님',
#  '파워풀한 풍뎅이님',
#  '탈출한 다람쥐님',
#  '귀여운 오오리님',
#  '곰을 잡은 언니님',
#  '놀라운 날다람쥐님',
#  '세상좋은 그대님',
#  '귀여운 햄찌님',
#  '구르는 오오리님',
#  '놀라운 오빠님',
#  '귀여운 햄스터님',
#  '구르는 거북이님',
#  '그대의 곰님',
#  '신비로운 햄쥐님',
#  '천국의 날다람쥐님',
#  '인형 잡은 오리님',
#  '신비로운 햄스터님',
#  '클린한 오리님',
#  '감옥의 소시지님',
#  '날라가는 개구리님',
#  '탈출한 소시지님',
#  '깜찍한 오빠님',
#  '천국의 오리님',
#  '여행 중인 그대님',
#  '곰을 잡은 형님',
#  '여행 중인 다람쥐님',
#  '클린한 오오리님',
#  '클린한 소시지님',
#  '날으는 누나님',
#  '그대의 풍뎅이님',
#  '신비로운 오빠님',
#  '천국의 곰님',
#  '날으는 쌩쌩이님',
#  '감옥의 북극곰님',
#  '귀여운 소시지님',
#  '깜찍한 누나님',
#  '구르는 그대님',
#  '클린한 그대님',
#  '굴러가는 날다람쥐님',
#  '파워풀한 풍뎅이님',
#  '각막의 언니님',
#  '궁금한 북극곰님',
#  '세상좋은 그대님',
#  '클린한 개구리님',
#  '구르는 오리님',
#  '궁금한 풍뎅이님',
#  '귀여운 햄쥐님',
#  '각막의 햄찌님',
#  '날으는 햄쥐님',
#  '클린한 날다람쥐님',
#  '궁금한 쌩쌩이님',
#  '신비로운 소시지님',
#  '뛰는 쌩쌩이님',
#  '궁금한 언니님',
#  '탈출한 누나님',
#  '감옥의 누나님',
#  '뛰는 누나님',
#  '탈출한 개구리님',
#  '뛰는 누나님',
#  '파워풀한 누나님',
#  '신비로운 햄쥐님',
#  '곰을 잡은 그대님',
#  '인형 잡은 햄스터님',
#  '깜찍한 거북이님',
#  '뛰는 햄스터님',
#  '구르는 붕붕이님',
#  '굴러가는 날다람쥐님',
#  '탈출한 undefined님',
#  '탈출한 햄스터님',
#  '감옥의 오빠님',
#  '뛰는 쌩쌩이님',
#  '신비로운 날다람쥐님',
#  '뛰는 쌩쌩이님',
#  '여행 중인 undefined님',
#  '그대의 곰님',
#  '궁금한 북극곰님',
#  '날으는 소시지님',
#  '신비로운 햄스터님',
#  '천국의 그대님',
#  '클린한 오빠님',
#  '신비로운 언니님',
#  '천국의 거북이님',
#  '날으는 거북이님',
#  '감옥의 북극곰님',
#  '인형 잡은 쌩쌩이님',
#  '깜찍한 곰님',
#  '궁금한 곰님',
#  '날으는 풍뎅이님',
#  '굴러가는 햄찌님',
#  '굴러가는 그대님',
#  '날라가는 쌩쌩이님',
#  '세상좋은 형님',
#  '놀라운 햄스터님',
#  '굴러가는 오오리님',
#  '천국의 undefined님',
#  '클린한 소시지님',
#  '곰을 잡은 그대님',
#  '곰을 잡은 언니님',
#  '굴러가는 다람쥐님',
#  '탈출한 곰님',
#  '깜찍한 거북이님',
#  '뛰는 풍뎅이님',
#  '귀여운 오빠님',
#  '여행 중인 거북이님',
#  '깜찍한 북극곰님',
#  '날라가는 개구리님',
#  '구르는 오리님',
#  '궁금한 곰님',
#  '각막의 오오리님',
#  '깜찍한 그대님',
#  '그대의 소시지님',
#  '감옥의 날다람쥐님',
#  '탈출한 다람쥐님',
#  '굴러가는 다람쥐님',
#  '깜찍한 거북이님',
#  '여행 중인 곰님',
#  '천국의 undefined님',
#  '뛰는 다람쥐님',
#  '굴러가는 날다람쥐님',
#  '각막의 북극곰님',
#  '탈출한 북극곰님',
#  '파워풀한 햄찌님',
#  '신비로운 undefined님',
#  '날라가는 오오리님',
#  '곰을 잡은 누나님',
#  '천국의 거북이님',
#  '곰을 잡은 북극곰님',
#  '그대의 개구리님',
#  '뛰는 형님',
#  '귀여운 햄쥐님',
#  '세상좋은 오리님',
#  '각막의 형님',
#  '놀라운 그대님',
#  '여행 중인 소시지님',
#  '신비로운 거북이님',
#  '각막의 붕붕이님',
#  '놀라운 오빠님',
#  '인형 잡은 햄스터님',
#  '파워풀한 undefined님',
#  '날라가는 형님',
#  '그대의 붕붕이님']

# %% [markdown]
# #### 리뷰 내용
# - 작성내용 tag :  a > div.v-card__text.d-flex.flex-column.px-16.py-20.px-md-26.py-md-36 > div.row.no-gutters.justify-space-between > div > div.d-flex.flex-column.v-card--default__content > div:nth-child(2) > div > div.col.content-area-before-text > div

# %%
review_content = browser.find_elements_by_css_selector('a > div.v-card__text.d-flex.flex-column.px-16.py-20.px-md-26.py-md-36 > div.row.no-gutters.justify-space-between > div > div.d-flex.flex-column.v-card--default__content > div:nth-child(2) > div > div.col.content-area-before-text > div')
type(review_content), type(review_content[0])
# Out:
# (list, selenium.webdriver.remote.webelement.WebElement)

# %%
# 리뷰 내용 리스트
review_content_list = []
for review_content in review_content :
    review_content_list.append(review_content.text)

review_content_list
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '입구에 들어가자마자 드는 생각은 대학병원 안과 외래에 온줄알았다 병원이 크고 파트가 정확히 나뉘어 있어서 놀랐고, 깔끔하고정돈됬지만,사람이 인산인해를 이루었다 아무래도 작은 눈불편함 부터 큰수술까지 하고 있어서 그런것 같았고,웬만한 장비들을 다 갖추고 있어서 그런것같다입구에 들어서면 바로 인포직원4명이 보인다 접수,수납으로 나뉘어 체계적이고 친절하셨다. 예약을했어도 번호표를 뽑고 진행되고 대기시간이 있었다 ㅠㅠ 이부분은 아쉬웠지만 예약을 않하면 더오래 기다리게 되니 예약은 필수다!(네이버 예약) 원장선생님은 총 5명이었고 ,각자 전문 분야가 나뉘어있는듯각막질환,망막질환,백내장분야,녹내장분야 등 본인이 받아야할 진료 또는 수술에 맞춰서 예약할시 원장님 이력과 분야를보고 지정하여 예약할수도 있었다.병원은 크게 검사센터,진료센터,수술센터로 분류되어있고 체계적이었다 . 검사센터에는 간단한 시력검사부터,라식라섹을위한 검사, 백내장,망막검사등 디테일 한 검사등을위한 기계들이 분류되어있는듯 했다 처음보는 기계들도있어서 잘모르겠다 ..ㅎㅎ 렌즈실과 상담실 도 검사센터 파트에 분류되어있었다간단한 시력검사도 3가지로 나뉘어있고 시력검사후 정확한검사를위해 다른기계로 다시 검사를 진행해주기도 하였다 꼼꼼하고체계적이였다 그 결과? 에맞춰 진료실이 배정되는것 같기도하다 처음 가라고한 진료실과 다른진료실을 가라고했다아!참고로 나는 초진이라 따로 원장님을 정하지 않고 왔다 진료센터에는 진료실 5개와 처치실이 있었고 , 진료실 끝에는 망막수술,녹내장수술,백내장수술센터가 있었고 마취센터가따로 있는것 같았다진료실은 검사센터에서 가라고한 검사실로 가면 되고 기계음성이 이름을 호명하면 진료실로 들어가는 시스템 이었다나는 4번 진료실에 가서 앉아있으라했고 김정열 원장님께 배정되었다!사람이 많았지만 생각 보다 오래 기다리지는 않았던것같다 원장님과 진료실에서 눈에 이상이있는지 또 진료및검사를하는데 이때 눈시력 교정이 가능한지도 확인해 주신다(물론본인의 방문목적이 눈 시력수술과 관련됬다면 말이다. 교정술이 않되는 경우도 있다고 한다 눈의 질환등 의 이유로 )원장님과 상담및상담 시간은 10분정도 였고 친절하셨지만 환자가 많아 필요한 부분만 집어주시고 자세하게 라식,라섹,렌즈삽입술에 대해서는 상담실에서 담당 상담사가 배정되 따로 진행되었다.그래도 원장님께 눈에 상태나 교정술에대해 물어보면 상담을 해주시고 교정술보다는 현재 눈의 상태에 대해 자세히 이야기 해주신다 그리고 교정술에 대해서는 꼭 해야한다고 강요가 없으시고 현재 눈상태와 원장님의 검사에서 발견한 망막근처 점이 있는데 레이저로 가능하다면서 검사상 발견된 부분은 전부 집어주시고 어떻게 치료 할수 있는지 그리고 치료를 해야하는 상황인지 아닌지 정확히 알려주셔서 좋았다.무조건 시술하고 가라고,치료하라고 하는곳 들도 많은데 여기는 내가 선택 할 수 있게 해주는 곳 같아서 신뢰가 갔다!원장님과 눈상태에 대해 이야기 했다면 그걸 바탕으로 상담사가 배정되어 상담실에서 시력교정술에 대해 자세하게 궁금한점들을 편안하게 물어볼수 있었다 .사람마다 상담시간은 다른것 같다 나는 30분 가까이 상담을 했고 고민하는부분을 다 해결해주셨으며 좋았던점은 의사선생님과 상담사 모두 억지로 권유하지 않는다...!!장,단점과 시술비용 시간 그후 관리 까지 친절하게 설명해주신다 그리고 충분히 고민해보시라고 이야기 해주셨다. 내가 안내받은 라식 라섹 비용은 120만원 이었고 현재는 수험생 이벤트 중이라 수험생분들 에겐 가격이 저렴한것 같았다. 40%정도 할인된다고 했다 (라식,라섹,렌즈삽입술)라식라섹에도 종류가 있었고 그부분에서 가격차이가 발생하는데 본인에게 맞는걸로 상담후 결정 하면 될 것 같다 . 우선 최첨단 장비, 분업화된 시스템 , 전문의5명 지원들의 친절도 등 좋은 점과 신뢰가 가는 병원이 었다. 하지만! 사람이많아대기시간이 조금 있다는 점은 참고 해야할거같다시력교정술을 위한 검안비는 따로 들지않지만 가자마자 하게되는 기본 검안비와 눈상태 체크를 위한 검안비(원장님)는발생된다원장님을 만나는것 자체가 진료비로 들어간다고 했다. 예약하게되면 시력교정술을 위한 검사에 대해 자세히 설명해주신다 주의 사항들이 있으니 꼭 숙지 하고 가시길 바랍니다!!',
#  '평소 시력이 많이 검사를 해봐야겠다고 생각만 했는데검사비가 무료라서 좋았다직원 한분한분 너무 친절하시고 웃으면서 공감도 해주셨다검사를 친절히 도와주셔서 너무 편한 마음으로 있었음 수술 후 추후에도 시력이 재수술도 무료로 해주시고 평생 관리도 가능하다고 해서 안전하고 좋은 병원이라는 생각이 들었다직원분들 너무 친절하시고 사람들이 많고 바쁘면 간혹 예민한 선생님들도 계시는데 지에스는 전혀 없었고 오히려 다 너무 좋았다친절하시긴 한데 너무 바쁘다 보니 약간 설명이 부족하거나 진행이 빠른 것이 없지 않아 있었다 전체적으로 상담받아보기 잘했다고 느낀 병원이다!스마일라식 회복시간이 4시간이면 가능하다는 것과 재수술 무료, 평생관리 가능한게 최고다단점으로는 가격.... 가격과 대기시간이 조금 있는 것?!그래도 만족한다!',
#  '',
#  '',
#  '',
#  '',
#  '6살부터 시력이 안 올라와서 안경쓴 아이라 내내 드림렌즈 고민했었는데요. 아이가 어리기도 하고 겁도 많아서 엄두를 못냈었는데 시력이 자꾸 떨어져서 더이상 미룰 수 없어서 결정했습니다. 장단점 잘 설명해주셨고, 아이도 생각보다 잘 적응해서 만족합니다.',
#  '아이의 근시가 진행되는 걸 늦추기 위해 마이오가드를 처방 받고 있습니다. \n조금 더 일찍 시작했다면 아이 시력이 더 좋지 않았을까 하는 아쉬움이 남아요. \n아이는 근시 진행이 정말 빠르더라구요.. \n시설은 좀 오래되었지만, 근방에서 아주 인기있는 병원입니다. \n늘 대기가 많아요. \n대기실이 늘 만석이예요. \n대기실도 그만큼 넓습니다.\n선생님께서 친절하고 차분하게 설명해주세요. \n믿음이 가는 병원입니다.',
#  '근시가 심한 아이인데, 아이숲 안과에서 여러 장비들이 있어서 정확한 검진을 할 수 있었고 이샘 원장님께 친절한 진료를 받을 수 있었어요. 현재 드림렌즈를 맞춰 착용중이고 만족하며 다니고 있습니다.',
#  '우선 젊은분이셨고 진료는 전체적으로 다 만족해요. \n제가 눈이 불빛 깜빡이듯 흔들리는 증상와 눈이 너무 시려서 방문 드렸는데 왜 이런 증상이 나타나는 건지에 대해서와 예방법에 대해서도 안내해주셨어요.\n안타깝게 흔들리는 증상은 나이가 들어감에 따라 어쩔 수 없다고 하시더라구요 ㅠ \n\n그리고 망막 검사를 통해서 레이저 시술도 권유 받아서 예약 날자 잡았어요. \n신경이 얇아서? 약해서? 레이저로 치료야한다고 하더라구요..^^\n\n진료는 잘 받았는데.... \n치료비가.... \n뭐... 물론 라식이후 검진비가 합쳐져서 ... 뭐 이건 괜찮았어요... \n\n근데 비보험 되는 안약을 같이 처방해주셨는데... \n세상에...11000원짜리 3개를 넣어주셨어요...;; \n저는 1개인줄 알았는데 약국 갔더니 3개 처방되어있더라구요... \n처방전을 새로 받고 하기가 번거로워서 그냥.. 결제 했는데 \n그날 처방전 약값만 48,000원... \n병원진료비까지하면...... ㅠ 부담되더라구요 ㅠ \n그게.. 좀... 아쉬웠어요.. \n\n그리고 라식 수술해주셨던 정원장님께 진료 받고 싶었는데 \n예약부서에서 안내를 잘못해줘서 예약이 안되어서 이 부분도 좀 아쉬웠어요. \n\n차후에 개선된 모습으로 다시 뵙고 싶어요..* \n\n그래도 믿고 다니는 안과이니까요...! ㅎ \n\n다음번에는 처방전은 인공눈물만 받을꺼예요 ㅠ \n\n진료비 영수증 인증을 못해서 다시써요 ㅎ',
#  '아이가 눈이 나쁘다고 해서 진료보러 갔어요\n대면 진료시 아이에 대해 꼼꼼히 물어봐주시고\n여러번 양쪽눈 확인하시고 아이상태에 대해 꼼꼼히 얘기해주셔서 걱정되는 입장에서 감사했습니다.\n직원분들도 친절하세요',
#  '눈이 충혈되어서 방문했는데 원장선생님 친절하게 봐주시고 병원넓고 쾌적해요~\n접수 굿닥으로 하니까 편리하고 간호사분들도 친절하세요.\n드림렌즈로 유명한지 토요일은 예약 안하면 사람이 많아서 대기 9번인데 30분정도 기다렸어요.',
#  '안구건조증+알레르기로 처음 방문했어요\n간호사분도 원잘님도 친절해서 좋았구요\n눈 상태가 어떤지 꼼꼼히 진찰해주시고 설명해주시고\n안약 넣는 방법도 알려주셨어요\n안과 방문 할일 또 있으면 여기 방문하려구요',
#  '시력이 갑작이 떨어진듯 하고 침침해서 너무 불편해서 내원 해서 시력 검사와 함께 알러지 반응 가려워서 안약과 함께 정밀 검사를 받아왔어요. 너무 편안하게 해주셔서 어려움 없이 아프지 않게 받았고 선생님이 너무 꼼꼼하시고 내공이 깊으신 분이셔서 믿음이 갔습니다 다시 한번 감사드려요 시력 검사 받기 추천 합니다',
#  '계속 진료받고 있는 병원입니다 안구건조로 방문했는데 눈 망막에 주름이 있다고 해서 정기적으로 진료받고 있습니다 의사선생님께서 항상 친절하게 설명해주셔서 좋습니다 환자가 많아도 대충 보시지 않고 질문에 자세한 설명도 해주시고 병원도 새로 이사해서 더 넓어졌네요',
#  '미사로 이사와서 처음 다니게 된 안과입니다 주변에서 추천을 해주셨고 역시 병원 의료진 모두 친절하시고 병원도 크고 깨끗합니다 의사선생님께서도 자세하게 설명해주시고 진료와 함께 주의할 점도 자세히 설명해주셨어요 앞으로 안과 관련해서는 연세봄안과 계속 진료받을 예정입니다',
#  '약국에서 약을 먹었는데도 차도가 없이 갑자기 난 다래끼가 심해서 진료보고 왔어요. 아마도 약먹고 치료받으면 다래끼는 금방 좋아질 것 같아요 매우만족합니다 다음에 또 방문하려고 해요.',
#  '눈아래가 부어올라 급 검색으로 방문한 안과인데 원장님 친절하시고 부은 부위 상세하게 살펴봐주셨어요^^\n병원규모크고 깨끗하고 드림렌즈로 유명하다더니 평일 아침일찍인데도 아이데리고온 학부모들이 많더라구요.',
#  '회사 근처라 갑작스러운 알러지와 눈 염증으로 우연하게 워크인으로 들어갔다가 오랜 시간 다니고 있습니다 워낙 병원 규모가 크고 선생님들도 많습니다 타병원과 다른것은 들어가면 바로 진료전에 검사를 눈에 상태를 기계로 체크해 봐주십니다 꼼꼼하게 눈에 상태와 어떤 방식으로 집에서 해야 하는지 후처치까지 알려 주셔서 정말 도움이 많이 되서 항상 애용중인 안과 입니다',
#  '집에서 가까운 안과 중에 큰 병원인 것 같아서 방문했어요.\n다래끼가 생겨 진료 목적으로 방문했고, 눈이 잘 보이지 않아 시력검사, 안구건조도 있어서 함께 문의했어요.\n사람 없는 시간에 방문해서 바로 시력검사하고 진료 받았고요.\n원하는 진료만 딱 깔끔하게 했어요.\n처방 받은 약 먹고 바로 나았어요.\n신도시에 있는 병원이다 보니 시설은 당연히 좋았고요. 직원분들도 친절하셨고 전체적으로 만족했어요.',
#  '의사샘이 1명이라 대기가 길까봐 좀 망설였는데요\n직원분들이 많아 기다리는거 없이 검사하고 진료 받았어요\n원장선생님 너무 친절하고요\n질문에 대한 대답도 정말 이해와 납득이 가게 해 주세요\n다음에도 봄빛안과 가려고요\n시설도 진짜 좋아요\n다만 진료비가 좀 나가던데...\n적정진료비인지 아닌지 비교대상이 없어 잘 모르겠네요\n어쨌든 원장샘이 좋아서 재방문할 의시 100프로입니다',
#  '점점 아이패드보는시간도 늘어나고 걱정이되더라구요..그래서 이제 어느정도 의사소통도되고해서 시력검하를하러다녀왔어요!\n\n여러가지검사로 아이가 잘따라올수있거 잘진료해주셨어요! 진료다하고 챙겨주신 캔디에 아이기분이 너무좋아졌어용ㅋㅋ',
#  '아이가 드림렌즈착용으로 3개월에 한번씩 검진을갑니다 사람이 정말많은데도 모든 직원분들 의사쌤들이 다 친절하시고 편안하세요 안과도 깨끗하고 넓고 시설도 최고이구요 앞으로도 쭈욱 삼성안과 이용할 예정입니다',
#  '6살 딸아이가 갑자기 눈에 충혈이 되고 열이나서 급히 하원 후 찾아간 안과입니다. 신식 건물이고, 지하1층부터 지상5층까지 전부 안과입니다. 수술실도 있고 진료실, 대기공간도 매우 넓습니다.\n평일 오후 17시쯤 도착했는데, 대기인원 없이 바로 진료가 가능했습니다. 그날의 경우, 오전에 환자가 많았고 오후에는 수술 환자들이 많았다고 하시더라고요. 검사기계들도 많고 신식이라, 둘러보는것만으로도 최첨단 의료시설에 와있는 느낌이 듭니다.\n접수하자마자 의사샘 진료 가능했고, 아이 눈 상태 확인 후 설명 친절하게 잘해주셨습니다. 일단 단순 염증인지 아니면 아데노바이러스 성인지는 몇일 약을 투약해봐야 알 수 있다고 안약2개를 처방해주셨습니다. (성인에게 처방되는 안약과 동일하던데, 이 부분은 조금 더 설명해주면 좋지않았을까 싶어요. ^^) 다행히 안약 투약 후 바로 나아졌어요. 조금 센 약은 아니었나 궁금도 하네요. \n\n접수수납 해주시는 선생님들도 매우 친절하시고, 비치되어있는 부채도 선물로 주셔서 여름에 잘 사용중입니다. 지금의 친절함이 오래 유지되길 바라봅니다',
#  '아이가 난시가 있어서 공안과병원 강동점을 다닌지 3년차 입니다. 처음에 영유아 시력 검사시 아이가 잘 못보는 듯한 느낌이 들어서 동네안과 4곳, 경희대병원을 거쳐 공안과로 정하고 공안과에서 꾸준히 감사하고 있습니다! 일찍이 발견해서 시력도 점점 좋아지고 (짝눈이었어요ㅠ) 정말 효과를 많이 봐서 무한 감사 드립니다! 특히나 여러 병원에서 시력 검사를 해본 결과 (아이눈 괜찮다고 안경 안써도 된다는 곳도 있었고 아이가 시력 검사 협조가 잘 안된다며 더 커서 오라고 한 곳도 있었어요 ㅠㅠ) 공안과 시력 검사실은 정말 체계적이고 최고라고 말할수 있어요!! 시력검사시에 이것저것 해주시는데 정말 믿고 다닐수 있는 병원이예요!! \n공안과 선생님들 너무 감사합니다~~',
#  '알러지 있어서 갔는데\n약처방 받고 좋아졌어요\n\n들어가면서부터 데스크와 의사선생님까지\n너무 친절하시더라고요\n기분좋게 진료받고 왔습니다\n\n눈이 예민하고건조증도 있는데 \n바로 진료하고 처방해주었어요']

# %% [markdown]
# #### 리뷰 별점
# - 별점 tag :

# %%
review_star = browser.find_elements_by_css_selector(' a > div.v-card__text.d-flex.flex-column.px-16.py-20.px-md-26.py-md-36 > div.pt-8.pt-md-14.mt-auto.mb-n4 > div > div:nth-child(2)')

# %%
# 리뷰 별점 리스트
review_star_list = []
for review_star_element in review_star:
    review_star_t = review_star_element.get_attribute('aria-label')
    review_star_list.append(review_star_t)
review_star_list
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# #### 리뷰 병원명
# - 병원명 tag : div.pt-8.pt-md-14.mt-auto.mb-n4 > div > div:nth-child(1) > a > span

# %%
review_hospital = browser.find_elements_by_css_selector('div.pt-8.pt-md-14.mt-auto.mb-n4 > div > div:nth-child(1) > a > span')
type(review_hospital), type(review_hospital[0])
# Out:
# (list, selenium.webdriver.remote.webelement.WebElement)

# %%
# 리뷰 병원 이름 리스트
review_hospital_list = []
for review_hospital in review_hospital :
    review_hospital_list.append(review_hospital.text)

review_hospital_list
# Out:
# ['',
#  '',
#  '',
#  '',
#  '지에스안과의원(GS안과)',
#  '카이안과의원',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '명지더봄안과의원',
#  '밝은빛안과의원',
#  '아이숲안과의원',
#  '온누리안과의원',
#  '서울다봄안과의원',
#  '드림서울안과의원',
#  '명동안과의원',
#  '김앤김안과의원',
#  '연세봄안과의원',
#  '연세봄안과의원']
